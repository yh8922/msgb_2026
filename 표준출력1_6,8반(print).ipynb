# %% [markdown]
# <a href="https://colab.research.google.com/github/yh8922/msgb_2026/blob/main/%ED%91%9C%EC%A4%80%EC%B6%9C%EB%A0%A51_6%2C8%EB%B0%98(print).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print()함수 ---주석
print("안녕하세요")
print("정보")
# Out:
#   File "/tmp/ipython-input-3285496928.py", line 3
#     print("정보")
#     ^
# IndentationError: unexpected indent

# %%
# 주석처리입니다.
# 여긴 실행되지 않아요

# %%
'''
이 부분은 주석 처리가 됩니다.
여러 줄을 이렇게 작성할 수 있습니다.
'''
print("실행되는 코드")
# Out:
# 실행되는 코드

# %%
#print() 여러 줄 출력
print('''
안녕하세요
정보
1학년 6_8반
프로그래밍
''')
# Out:
# 안녕하세요
# 정보
# 1학년 6_8반
# 프로그래밍

# %%
#print() 여러 내용 출력 (,) , + 기호 사용 예시
print("1학년","6_8반","정보")
print("1학년"+"6_8반"+"정보")
# Out:
# 1학년 6_8반 정보
# 1학년6_8반정보

# %%
#print() , sep 구분 기호
print("1학년","6_8반","정보",sep='??')
# Out:
# 1학년??6_8반??정보

# %%
#print() , end 기호
print("1학년","6_8반","정보",end='        ')
print("1학년"+"6_8반"+"정보")
# Out:
# 1학년 6_8반 정보        1학년6_8반정보

# %%
#f-문자열 형식
